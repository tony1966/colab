# %% [markdown]
# <a href="https://colab.research.google.com/github/tony1966/colab/blob/main/reinforcement_learning_ch3_resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Activation, Add, BatchNormalization 
from tensorflow.keras.layers import Conv2D, Dense
from tensorflow.keras.layers import GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (10000, 32, 32, 3)
# (10000, 10)

# %%
# 建構卷積層
def conv(filters, kernel_size, strides=1):
    return Conv2D(filters, kernel_size, strides=strides, padding='same', 
            use_bias=True, kernel_initializer='he_normal', 
            kernel_regularizer=l2(0.0001))

# %%
# 建構殘差塊 A
def first_residual_unit(filters, strides):
    def f(x):
        # 正規化 → ReLU 激活
        x=BatchNormalization()(x)
        x_b=Activation('relu')(x)
        # 卷積層 → 正規化 → ReLU 激活
        x=conv(filters // 4, 1, strides)(x_b)
        x=BatchNormalization()(x)
        x=Activation('relu')(x)        
        # 卷積層 → 正規化 → ReLU 激活
        x=conv(filters // 4, 3)(x)
        x=BatchNormalization()(x)
        x=Activation('relu')(x)
        # 卷積層
        x=conv(filters, 1)(x)
        # 調整捷徑之 shape 的尺寸
        x_b=conv(filters, 1, strides)(x_b)
        # Add
        return Add()([x, x_b])
    return f

# %%
# 建構殘差塊 B
def residual_unit(filters):
    def f(x):
        x_b = x        
        # → 正規化 → ReLU 激活
        x=BatchNormalization()(x)
        x=Activation('relu')(x)        
        # 卷積層 → 正規化 → ReLU 激活
        x=conv(filters // 4, 1)(x)
        x=BatchNormalization()(x)
        x=Activation('relu')(x)        
        # 卷積層 → 正規化 → ReLU 激活
        x=conv(filters // 4, 3)(x)
        x=BatchNormalization()(x)
        x=Activation('relu')(x)        
        # 卷積層
        x=conv(filters, 1)(x)
        # Add
        return Add()([x, x_b])
    return f

# %%
# 建構殘差塊 A×1 與 殘差塊 B×17
def residual_block(filters, strides, unit_size):
    def f(x):
        x=first_residual_unit(filters, strides)(x) # 1 個殘差塊 A
        for i in range(unit_size-1):       # 17 個殘差塊 B
            x=residual_unit(filters)(x)
        return x
    return f

# %%
# 輸入層
input=Input(shape=(32,32, 3)) # CIFAR 圖片 32x32, RGB 三通道
# 卷積層
x=conv(16, 3)(input) # 16 個 3x3 卷積核
# 殘差塊 x 54
x=residual_block(64, 1, 18)(x)   # 第一組殘差塊
x=residual_block(128, 2, 18)(x)  # 第二組殘差塊
x=residual_block(256, 2, 18)(x)  # 第三組殘差塊
# → 正規化 → ReLU 激活
x=BatchNormalization()(x)
x=Activation('relu')(x)
# 池化層
x=GlobalAveragePooling2D()(x)
# 密集層
output=Dense(10, activation='softmax', kernel_regularizer=l2(0.0001))(x)
# 建構模型
model=Model(inputs=input, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 16)  64          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 16)   272         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   1088        ['activation[0][0]']
#
#  add (Add)                      (None, 32, 32, 64)   0           ['conv2d_3[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['add[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 16)   1040        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   1088        ['activation_5[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 64)   0           ['conv2d_7[0][0]',
#                                                                   'add[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['add_1[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 16)   1040        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 16)  64          ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_8[0][0]']
#
#  add_2 (Add)                    (None, 32, 32, 64)   0           ['conv2d_10[0][0]',
#                                                                   'add_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 64)  256         ['add_2[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 16)  64          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_11[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['conv2d_13[0][0]',
#                                                                   'add_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['add_3[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_14[0][0]']
#
#  add_4 (Add)                    (None, 32, 32, 64)   0           ['conv2d_16[0][0]',
#                                                                   'add_3[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  256         ['add_4[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_17[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 64)   0           ['conv2d_19[0][0]',
#                                                                   'add_4[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  256         ['add_5[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 16)  64          ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 16)  64          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_20[0][0]']
#
#  add_6 (Add)                    (None, 32, 32, 64)   0           ['conv2d_22[0][0]',
#                                                                   'add_5[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 64)  256         ['add_6[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_23[0][0]']
#
#  add_7 (Add)                    (None, 32, 32, 64)   0           ['conv2d_25[0][0]',
#                                                                   'add_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 64)  256         ['add_7[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 16)  64          ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_26[0][0]']
#
#  add_8 (Add)                    (None, 32, 32, 64)   0           ['conv2d_28[0][0]',
#                                                                   'add_7[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 64)  256         ['add_8[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_29[0][0]']
#
#  add_9 (Add)                    (None, 32, 32, 64)   0           ['conv2d_31[0][0]',
#                                                                   'add_8[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 64)  256         ['add_9[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 16)  64          ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 16)  64          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_32[0][0]']
#
#  add_10 (Add)                   (None, 32, 32, 64)   0           ['conv2d_34[0][0]',
#                                                                   'add_9[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 32, 32, 64)  256         ['add_10[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 32, 32, 16)  64          ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 32, 32, 16)  64          ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_35[0][0]']
#
#  add_11 (Add)                   (None, 32, 32, 64)   0           ['conv2d_37[0][0]',
#                                                                   'add_10[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 32, 32, 64)  256         ['add_11[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 32, 32, 16)  64          ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 16)  64          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_38[0][0]']
#
#  add_12 (Add)                   (None, 32, 32, 64)   0           ['conv2d_40[0][0]',
#                                                                   'add_11[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 64)  256         ['add_12[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 16)  64          ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 16)  64          ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_41[0][0]']
#
#  add_13 (Add)                   (None, 32, 32, 64)   0           ['conv2d_43[0][0]',
#                                                                   'add_12[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 64)  256         ['add_13[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 16)  64          ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 16)  64          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_44[0][0]']
#
#  add_14 (Add)                   (None, 32, 32, 64)   0           ['conv2d_46[0][0]',
#                                                                   'add_13[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 64)  256         ['add_14[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 16)  64          ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 16)  64          ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_47[0][0]']
#
#  add_15 (Add)                   (None, 32, 32, 64)   0           ['conv2d_49[0][0]',
#                                                                   'add_14[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 32, 32, 64)  256         ['add_15[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 32, 32, 16)  64          ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 32, 32, 16)  64          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_50[0][0]']
#
#  add_16 (Add)                   (None, 32, 32, 64)   0           ['conv2d_52[0][0]',
#                                                                   'add_15[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 32, 32, 64)  256         ['add_16[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 32, 32, 16)   1040        ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 32, 32, 16)  64          ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 32, 32, 16)  64          ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 32, 32, 64)   1088        ['activation_53[0][0]']
#
#  add_17 (Add)                   (None, 32, 32, 64)   0           ['conv2d_55[0][0]',
#                                                                   'add_16[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 64)  256         ['add_17[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 16, 16, 32)   2080        ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 32)  128         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 32)  128         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 16, 16, 128)  4224        ['activation_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 128)  8320        ['activation_54[0][0]']
#
#  add_18 (Add)                   (None, 16, 16, 128)  0           ['conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 128)  512        ['add_18[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 16, 16, 32)   4128        ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 32)  128         ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_58[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 16, 16, 32)  128         ['conv2d_61[0][0]']
#  ormalization)
#
# ...
#  add_47 (Add)                   (None, 8, 8, 256)    0           ['conv2d_147[0][0]',
#                                                                   'add_46[0][0]']
#
#  batch_normalization_144 (Batch  (None, 8, 8, 256)   1024        ['add_47[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_144[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_144[0][0]']
#
#  batch_normalization_145 (Batch  (None, 8, 8, 64)    256         ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_145[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_145[0][0]']
#
#  batch_normalization_146 (Batch  (None, 8, 8, 64)    256         ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_146[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_146[0][0]']
#
#  add_48 (Add)                   (None, 8, 8, 256)    0           ['conv2d_150[0][0]',
#                                                                   'add_47[0][0]']
#
#  batch_normalization_147 (Batch  (None, 8, 8, 256)   1024        ['add_48[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_147[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_147[0][0]']
#
#  batch_normalization_148 (Batch  (None, 8, 8, 64)    256         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_148[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 8, 8, 64)    256         ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_149[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_149[0][0]']
#
#  add_49 (Add)                   (None, 8, 8, 256)    0           ['conv2d_153[0][0]',
#                                                                   'add_48[0][0]']
#
#  batch_normalization_150 (Batch  (None, 8, 8, 256)   1024        ['add_49[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_150[0][0]']
#
#  batch_normalization_151 (Batch  (None, 8, 8, 64)    256         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_151[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_151[0][0]']
#
#  batch_normalization_152 (Batch  (None, 8, 8, 64)    256         ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_152[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_152[0][0]']
#
#  add_50 (Add)                   (None, 8, 8, 256)    0           ['conv2d_156[0][0]',
#                                                                   'add_49[0][0]']
#
#  batch_normalization_153 (Batch  (None, 8, 8, 256)   1024        ['add_50[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_153[0][0]']
#
#  batch_normalization_154 (Batch  (None, 8, 8, 64)    256         ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_154[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_154[0][0]']
#
#  batch_normalization_155 (Batch  (None, 8, 8, 64)    256         ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_155[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_155[0][0]']
#
#  add_51 (Add)                   (None, 8, 8, 256)    0           ['conv2d_159[0][0]',
#                                                                   'add_50[0][0]']
#
#  batch_normalization_156 (Batch  (None, 8, 8, 256)   1024        ['add_51[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_156[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_156[0][0]']
#
#  batch_normalization_157 (Batch  (None, 8, 8, 64)    256         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_157[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_157[0][0]']
#
#  batch_normalization_158 (Batch  (None, 8, 8, 64)    256         ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_158[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_158[0][0]']
#
#  add_52 (Add)                   (None, 8, 8, 256)    0           ['conv2d_162[0][0]',
#                                                                   'add_51[0][0]']
#
#  batch_normalization_159 (Batch  (None, 8, 8, 256)   1024        ['add_52[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_159[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 8, 8, 64)     16448       ['activation_159[0][0]']
#
#  batch_normalization_160 (Batch  (None, 8, 8, 64)    256         ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_160[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 8, 8, 64)     36928       ['activation_160[0][0]']
#
#  batch_normalization_161 (Batch  (None, 8, 8, 64)    256         ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 8, 8, 64)     0           ['batch_normalization_161[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 8, 8, 256)    16640       ['activation_161[0][0]']
#
#  add_53 (Add)                   (None, 8, 8, 256)    0           ['conv2d_165[0][0]',
#                                                                   'add_52[0][0]']
#
#  batch_normalization_162 (Batch  (None, 8, 8, 256)   1024        ['add_53[0][0]']
#  Normalization)
#
#  activation_162 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_162[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['activation_162[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           2570        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,740,042
# Trainable params: 1,715,818
# Non-trainable params: 24,224
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=SGD(momentum=0.9), 
      metrics=['acc'])

# %%
# 設定訓練集的 ImageDataGenerator
train_gen=ImageDataGenerator( 
    featurewise_center=True, 
    featurewise_std_normalization=True,
    width_shift_range=0.125, 
    height_shift_range=0.125, 
    horizontal_flip=True)
# 設定測試集的 ImageDataGenerator
test_gen=ImageDataGenerator(
    featurewise_center=True, 
    featurewise_std_normalization=True)
for data in (train_gen, test_gen):
    data.fit(train_images)

# %%
# 設定 LearningRateScheduler
def step_decay(epoch): # 以 epoch 為單位傳回新的學習率
    x=0.1  # 初始學習率
    if epoch >= 80: x=0.01  # 第 80 週期後學習率降為 0.01
    if epoch >= 120: x=0.001 # 第 120 週期後學習率降為 0.001
    return x
lr_decay=LearningRateScheduler(step_decay, verbose = 1) # 指定學習率指配函式

# %%
# 訓練模型
batch_size=128
history=model.fit(
    train_gen.flow(train_images, train_labels, batch_size=batch_size),
    epochs=120,
    steps_per_epoch=train_images.shape[0] // batch_size,
    validation_data=test_gen.flow(test_images, test_labels, 
                   batch_size=batch_size),
    validation_steps=test_images.shape[0] // batch_size,
    callbacks=[lr_decay])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.1.
# Epoch 1/120
# 390/390 [==============================] - 150s 316ms/step - loss: 4.5365 - acc: 0.3666 - val_loss: 4.2972 - val_acc: 0.4253 - lr: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.1.
# Epoch 2/120
# 390/390 [==============================] - 127s 325ms/step - loss: 3.7190 - acc: 0.5487 - val_loss: 3.7029 - val_acc: 0.5171 - lr: 0.1000
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.1.
# Epoch 3/120
# 390/390 [==============================] - 125s 319ms/step - loss: 3.1798 - acc: 0.6336 - val_loss: 3.4535 - val_acc: 0.5363 - lr: 0.1000
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.1.
# Epoch 4/120
# 390/390 [==============================] - 125s 321ms/step - loss: 2.7532 - acc: 0.6946 - val_loss: 3.0118 - val_acc: 0.5874 - lr: 0.1000
# Epoch 5/120
# 390/390 [==============================] - 125s 321ms/step - loss: 2.4200 - acc: 0.7293 - val_loss: 2.4970 - val_acc: 0.6753 - lr: 0.1000
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.1.
# Epoch 6/120
# 390/390 [==============================] - 125s 321ms/step - loss: 2.1496 - acc: 0.7564 - val_loss: 2.1602 - val_acc: 0.7226 - lr: 0.1000
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.1.
# Epoch 7/120
# 390/390 [==============================] - 125s 321ms/step - loss: 1.9184 - acc: 0.7792 - val_loss: 1.9315 - val_acc: 0.7547 - lr: 0.1000
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.1.
# Epoch 8/120
# 256/390 [==================>...........] - ETA: 40s - loss: 1.7562 - acc: 0.7934

# %%
# 儲存模型
model.save('resnet.h5')

# %%
# 繪製圖形
plt.plot(history.history['acc'], label='acc')
plt.plot(history.history['val_acc'], label='val_acc')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
# 評估
test_loss, test_acc=model.evaluate(test_gen.flow(test_images, test_labels))
print('loss: {:.3f}\nacc: {:.3f}'.format(test_loss, test_acc ))

# %%
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(test_images[i])
plt.show()

test_predictions=model.predict(test_gen.flow(test_images[0:10], shuffle=False))
test_predictions=np.argmax(test_predictions, axis=1)
labels=['airplane', 'automobile', 'bird', 'cat', 'deer', 
    'dog', 'frog', 'horse', 'ship', 'truck']
print('前 10 筆預測標籤:',[labels[n] for n in test_predictions])
test_ans=np.argmax(test_labels[:10], axis=1)
print('前 10 筆原始標籤:',[labels[n] for n in test_ans])
